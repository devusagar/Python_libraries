# %% [markdown]
# NUMPY Library

# %%
#module importing 
import numpy as np

# %%
#Using Array 
A=np.array(5)
A
# Out:
# array(5)

# %%
#Finding dimension of that Array
np.ndim(A)
# Out:
# 0

# %%
#1D array
one=np.array([1,2,3,4,5])
one
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.ndim(one)
# Out:
# 1
